# %%
import pandas as pd
import numpy as np

df = pd.read_excel('TotalesSaldos.xlsx')
#df.head(6)
df[['año','Saldo_total']]
# Out:
#      año   Saldo_total
# 0   2020  361957525238
# 1   2021  277111012572
# 2   2020  375212155175
# 3   2021  263986630515
# 4   2020  115054484609
# 5   2021   84339028020
# 6   2020  161641454561
# 7   2021  124904496473
# 8   2020  212519664301
# 9   2021  129934477146
# 10  2020  250159192367
# 11  2021  128153306538
# 12  2020  181675772112
# 13  2021  106433133503
# 14  2020  298906655635
# 15  2021  158432941792

# %%
df["Var"] = (df['Saldo_total'] + df['Saldo_total'])/df['Saldo_total'].shift(-1)
#df.loc[Saldo_total.index % 2!=0, "Variacion"] = np.nan
#df["var2"] = df.Saldo_total.rolling(2).sum().shift(-1)
df
# Out:
#        regional   año  mo_oficina   Saldo_total  Saldo_vencido  \
# 0     Antioquia  2020      240152  361957525238    17984737495
# 1           NaN  2021      242923  277111012572    10466028184
# 2        Bogotá  2020      466499  375212155175    21834829293
# 3           NaN  2021      466499  263986630515    10963887054
# 4      Cafetera  2020      269284  115054484609     5349288470
# 5           NaN  2021      269284   84339028020     3119897954
# 6         Costa  2020      297886  161641454561    16853216703
# 7           NaN  2021      297886  124904496473     8736164302
# 8     Occidente  2020      440698  212519664301    11922633980
# 9           NaN  2021      440698  129934477146     5104330258
# 10      Oriente  2020      312611  250159192367     8886505430
# 11          NaN  2021      312611  128153306538     2852941316
# 12  Santanderes  2020      426487  181675772112    10167024866
# 13          NaN  2021      426487  106433133503     4100888488
# ...
